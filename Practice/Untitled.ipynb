# %%
import os
import cv2
from PIL import Image
import pytesseract as pt
from matplotlib import pyplot as plt

# %%
pt.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
img_path= '../img/'
images= [os.path.join(img_path, i) for i in os.listdir(img_path)]

images
# Out:
# ['../img/bound-text-1.jpg',
#  '../img/bound-text-2.jpg',
#  '../img/portu-text-1.jpg',
#  '../img/selfie-circle.jpg',
#  '../img/thumb-1920-316008 - painted.jpg',
#  '../img/thumb-1920-316008.jpg']

# %%
img= Image.open(images[0])
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x600 at 0x154A7284E88>

# %%
text = pt.image_to_string(img)
text
# Out:
# 'The best rev is\ngust moving rand\nting over it.\nDre ie someone\nthe satisfaction of\nwatching you suffer.\n\ning Pictures @ MastPhotos.com\n'
